# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

#data file
covid_data_file = "Resources/200505COVID19MEXICO_RAW.csv"
# Read the data
covid_df = pd.read_csv(covid_data_file,encoding = "latin-1")

#function for converting codes to strings based on catalogs
def replaceCodes(catalogName,columnName):
    catalog_file = f"CATALOGOS/{catalogName}.csv"
    catalog_df = pd.read_csv(catalog_file,encoding = "latin-1")
    for index, row in catalog_df.iterrows():
        code = row['CLAVE']
        value = row['DESCRIPCIÃN']
        covid_df[columnName] = covid_df[columnName].replace(code, value)
    print(covid_df[columnName].head())

#preview original data
covid_df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2020-05-05      0e056a       1       4           2     2
# 1          2020-05-05      108695       1       4           9     2
# 2          2020-05-05      0342f4       1      12          32     2
# 3          2020-05-05      0c09bc       1       4          15     2
# 4          2020-05-05      188377       1       4           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0            2            2              4              1  ...              2
# 1            9            9             15              2  ...              1
# 2           31           32              6              2  ...              2
# 3           15           15             58              2  ...              2
# 4            9            9              5              1  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# ...

# %%
# Bernardo Jardon

# SECTOR
# ENTIDAD_UM
# SEXO
# ENTIDAD_NAC
# ENTIDAD_RES
# MUNICIPIO_RES

# ORIGEN
catalog_file = "CATALOGOS/ORIGEN.csv"
catalog_df = pd.read_csv(catalog_file,encoding = "latin-1")
print(catalog_df)

column_name = "ORIGEN"
covid_df[column_name] = covid_df[column_name].replace(1, "USMER")
covid_df[column_name] = covid_df[column_name].replace(2, "FUERA DE USMER")
covid_df[column_name] = covid_df[column_name].replace(99, "NO ESPECIFICADO")

covid_df
# Out:
#    CLAVE     DESCRIPCIÃN
# 0      1            USMER
# 1      2   FUERA DE USMER
# 2     99  NO ESPECIFICADO
#        FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               2020-05-05      0e056a           USMER       4           2
# 1               2020-05-05      108695           USMER       4           9
# 2               2020-05-05      0342f4           USMER      12          32
# 3               2020-05-05      0c09bc           USMER       4          15
# 4               2020-05-05      188377           USMER       4           9
# ...                    ...         ...             ...     ...         ...
# 105659          2020-05-05      0f3cb0  FUERA DE USMER       4          25
# 105660          2020-05-05      0a9847  FUERA DE USMER      12          11
# 105661          2020-05-05      1c66c5           USMER      12          19
# 105662          2020-05-05      1d0929  FUERA DE USMER       4           2
# ...

# %%
# Odín Efrén Del Toro Reyna

# INTUBADO
# NEUMONIA
# NACIONALIDAD
# EMBARAZO
# HABLA_LENGUA_INDIG
# DIABETES

# TIPO_PACIENTE
catalog_file = "CATALOGOS/TIPO_PACIENTE.csv"
catalog_df = pd.read_csv(catalog_file,encoding = "latin-1")
print(catalog_df)
column_name = "TIPO_PACIENTE"
covid_df[column_name] = covid_df[column_name].replace(1, "AMBULATORIO")
covid_df[column_name] = covid_df[column_name].replace(2, "HOSPITALIZADO")
covid_df[column_name] = covid_df[column_name].replace(99, "NO ESPECIFICADO")

covid_df
# Out:
#    CLAVE     DESCRIPCIÃN
# 0      1      AMBULATORIO
# 1      2    HOSPITALIZADO
# 2     99  NO ESPECIFICADO
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-05-05      0e056a       1       4           2     2
# 1               2020-05-05      108695       1       4           9     2
# 2               2020-05-05      0342f4       1      12          32     2
# 3               2020-05-05      0c09bc       1       4          15     2
# 4               2020-05-05      188377       1       4           9     2
# ...                    ...         ...     ...     ...         ...   ...
# 105659          2020-05-05      0f3cb0       2       4          25     1
# 105660          2020-05-05      0a9847       2      12          11     2
# 105661          2020-05-05      1c66c5       1      12          19     2
# 105662          2020-05-05      1d0929       2       4           2     1
# ...

# %%
# Miguel Angel Bonachea Soto
columns_raw = [("SI_NO","EPOC"),("SI_NO","ASMA"),("SI_NO","INMUSUPR"),("SI_NO","HIPERTENSION"),("SI_NO","OTRA_COM"),("SI_NO","CARDIOVASCULAR"),("SI_NO","OBESIDAD"),("SI_NO","RENAL_CRONICA")]
for catcol in columns_raw:
    replaceCodes(catcol[0],catcol[1])
# Out:
# 0    NO
# 1    SI
# 2    NO
# 3    NO
# 4    NO
# Name: EPOC, dtype: object
# 0    NO
# 1    SI
# 2    SI
# 3    NO
# 4    NO
# Name: ASMA, dtype: object
# 0    NO
# 1    NO
# 2    NO
# 3    NO
# 4    NO
# Name: INMUSUPR, dtype: object
# 0    NO
# 1    SI
# 2    NO
# 3    NO
# 4    NO
# Name: HIPERTENSION, dtype: object
# 0    NO
# 1    NO
# 2    NO
# 3    NO
# 4    NO
# Name: OTRA_COM, dtype: object
# 0    NO
# 1    SI
# 2    NO
# 3    NO
# 4    NO
# Name: CARDIOVASCULAR, dtype: object
# 0    NO
# 1    SI
# 2    SI
# 3    NO
# 4    NO
# Name: OBESIDAD, dtype: object
# 0    NO
# 1    NO
# 2    NO
# 3    NO
# 4    NO
# Name: RENAL_CRONICA, dtype: object

# %%
# Pablo Arroyo
# TABAQUISMO
# OTRO_CASO
# RESULTADO
# MIGRANTE
# PAIS_NACIONALIDAD
# PAIS_ORIGEN
# UCI
